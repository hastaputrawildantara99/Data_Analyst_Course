# %% [markdown]
# FUNCTION ON VARIABLE

# %%
my_print_function = print

my_print_function(2+2, 5+5, 2*2)
id(my_print_function)
# Out:
# 4 10 4
# (136649635352144, 11654504, 11654504)

# %% [markdown]
# ## heading text
# **bold text**
# *Italic text*
# > block quote
# 1. ordered list 1
# 2. ordered list 2
# 3. ordered list 3
# - unordered list 1
# - unordered list 2
# - unordered list 3
# `code 2+2`
# ---
# [LINK](https://colab.research.google.com/drive/1UV2CvJsNwZxHPQ-4_enhzVdnafsgmNYb#scrollTo=OVj_0msUnJEn)
# ![alt text](/content/2025_07_09_11_50_IMG_4033.JPG)
